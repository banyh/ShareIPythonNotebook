# %%
# %matplotlib inline

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plot

# %%
cv2.__version__
# Out:
# '2.4.12'

# %%
img = cv2.imread("C:/Anaconda2/Menu/ipy_qtconsole.png")

# %%
plot.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plot.show()

# %%
# 下面的指令會產生一個視窗來放圖片
#cv2.imshow('image',img)
#cv2.waitKey(0)
#cv2.destroyAllWindows()
